# %% [markdown]
# ##Carga de datos / data_acquisition

# %%
import pandas as pd
import csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ruta_archivo= '/content/drive/MyDrive/UNAL_Cobros_I.csv'

# %%
pd= pd.read_csv(ruta_archivo, sep=';')

# %%
pd.head(10)
# Out:
#    CUST_CODE    NUMERO_FACTURA FECHA_ENVIO  CANTIDAD_FACTURAS  \
# 0   1.845701  A100173400951022  21/12/2022                  3
# 1   1.684716  A100173428261022  23/12/2022                  3
# 2   1.750373  A100173814331022  21/12/2022                  3
# 3   1.845437  A100173855691022  21/12/2022                  3
# 4   1.807786  A100173883841022  21/12/2022                  2
# 5   1.786779  A100173946231022  21/12/2022                  2
# 6   1.799535  A100173962051022  21/12/2022                  2
# 7   1.821349  A100173968841022  21/12/2022                  3
# 8   1.775121  A100174025131022  21/12/2022                  3
# 9   1.734951  A100174096211022  21/12/2022                  3
#
#   FECHA_DEVOLUCION IMPORTE_FACTURA FECHA_FACTURA ESCENARIO_RECOBRO  \
# 0       25/10/2022          263.68    01/10/2022               EMP
# 1       24/10/2022            3.93    01/10/2022               EMP
# 2       30/11/2022          178.74    01/10/2022               EMP
# ...
